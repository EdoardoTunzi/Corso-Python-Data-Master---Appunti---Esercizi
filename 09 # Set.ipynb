# %% [markdown]
# I set e le operazioni che è possibile fare su di essi ricordano molto gli insiemi in matematica. Un set in Python è un insieme di elementi :
# - non ordinati
# - univoci
# - modificabili
#
# Creazione di un set.

# %%
x = {"Giuseppe", "Enzo", "Giuseppe"}

y = set(["Giuseppe", "Giuseppe", "Enzo", "Francesca", "Marianna", "Francesca"])

print(type(x))

print(y)
# Out:
# <class 'set'>
# {'Marianna', 'Enzo', 'Giuseppe', 'Francesca'}

# %%
print(x)
# Out:
# {'Enzo', 'Giuseppe'}

# %% [markdown]
# Far notare come gli elementi non siano ripetuti anche se nell'insieme di partenza figurino 2 "Giuseppe".
# Si può creare un set anche con la funzione set(). Fare qualche esempio con una lista come argomento di set.

# %% [markdown]
# Presenza di elementi in un set:

# %%
"Enzo" in x
# Out:
# True

# %%
"enzo" in x
# Out:
# False

# %%
x1 = {"Giuseppe", "Enzo", "Andrea"}
x2 = {"Enzo", "Francesca", "Antonella"}

x1.union(x2)
# Out:
# {'Andrea', 'Antonella', 'Enzo', 'Francesca', 'Giuseppe'}

# %%
x1.intersection(x2)
# Out:
# {'Enzo'}

# %%
x1.issubset(x2)
# Out:
# False

# %%
x1 - x2
# Out:
# {'Andrea', 'Giuseppe'}

# %%
x1.add("Carla")

# %%
print(x1)
# Out:
# {'Carla', 'Enzo', 'Giuseppe', 'Andrea'}

# %%
len(x1)
# Out:
# 4

# %%
x1.remove("Andrea")

# %%
x1
# Out:
# {'Carla', 'Enzo', 'Giuseppe'}

# %% [markdown]
# Esempio: date due stringhe, stampare quante e quali parole in comune hanno queste 2 stringhe.

# %%
s1 = "Oggi è una splendida giornata"
s2 = "Sono convinto che andare al mare proprio in questa giornata non sia una splendida idea"

set1 = set(s1.split())
print(set1)
# Out:
# {'splendida', 'è', 'Oggi', 'una', 'giornata'}

# %%
set2 = set(s2.split())
print(set2)
# Out:
# {'convinto', 'proprio', 'andare', 'giornata', 'sia', 'una', 'splendida', 'che', 'idea', 'non', 'mare', 'Sono', 'in', 'questa', 'al'}

# %%
print(set1.intersection(set2))
# Out:
# {'una', 'giornata', 'splendida'}

# %%
print(set1.union(set2))
# Out:
# {'splendida', 'che', 'non', 'mare', 'una', 'questa', 'Oggi', 'in', 'convinto', 'proprio', 'andare', 'sia', 'al', 'è', 'idea', 'Sono', 'giornata'}
