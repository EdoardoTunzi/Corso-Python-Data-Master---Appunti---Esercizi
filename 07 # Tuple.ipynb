# %% [markdown]
# Una tupla è una struttura dati Python molto simile ad una lista, con le uniche differenze che:
# - una tupla è immutabile
# - accessi e le operazioni su una tupla sono generalmente più veloci rispetto a quelle su una lista

# %%
t = ('Giuseppe', 'Carla', 'Antonio', 'Filippa', 'Giuseppe', 'Giulia')

# %%
print(type(t))
print(len(t))
# Out:
# <class 'tuple'>
# 6

# %%
print(t[0])
print(t[-1])
# Out:
# Giuseppe
# Giulia

# %%
t[0] = "Filippo"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bp/vpf4133s7wjb10lznth5p4900000gn/T/ipykernel_7677/3420199699.py in <module>
# ----> 1 t[0] = "Filippo"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t =()
print(type(t))

t = (1, 2)
print(type(t))

t = (5)
print(type(t))

t = (5,)
print(type(t))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'int'>
# <class 'tuple'>

# %%
t = ("Giuseppe", "Carla", "Giulia")

n1, n2, n3 = t
print(n1)
print(n2)
print(n3)
# Out:
# Giuseppe
# Carla
# Giulia

# %%
n1, n2, n3 = "Giuseppe", "Carla", "Giulia"
print(n1, n2, n3)
# Out:
# Giuseppe Carla Giulia

# %%
n1, n2, n3 = ("Giuseppe", "Carla", "Giulia", "Francesco")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bp/vpf4133s7wjb10lznth5p4900000gn/T/ipykernel_7677/3900622244.py in <module>
# ----> 1 n1, n2, n3 = ("Giuseppe", "Carla", "Giulia", "Francesco")
#
# ValueError: too many values to unpack (expected 3)

# %%
n1, n2, n3 = ("Giuseppe", "Carla")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bp/vpf4133s7wjb10lznth5p4900000gn/T/ipykernel_7677/953432175.py in <module>
# ----> 1 n1, n2, n3 = ("Giuseppe", "Carla")
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
# quick swap with tuples

a = 5
b = 7

print(f"Before Legacy Swap: a -> {a}, b -> {b}")

temp = b
b = a
a = temp
print(f"After Legacy Swap: a -> {a}, b -> {b}")

a = 5
b = 7
print(f"Before Tuple Swap: a -> {a}, b -> {b}")
a, b = b, a
print(f"After Tuple Swap: a -> {a}, b -> {b}")
# Out:
# Before Legacy Swap: a -> 5, b -> 7
# After Legacy Swap: a -> 7, b -> 5
# Before Tuple Swap: a -> 5, b -> 7
# After Tuple Swap: a -> 7, b -> 5
